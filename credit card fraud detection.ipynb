# %% [markdown]
# CREDIT CARD FRAUD TRANSACTION PREDICTION

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("creditcard.csv")
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.describe(include="all")
# Out:
#                 Time            V1            V2            V3            V4  \
# count  284807.000000  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean    94813.859575  1.168375e-15  3.416908e-16 -1.379537e-15  2.074095e-15
# std     47488.145955  1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00
# min         0.000000 -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00
# 25%     54201.500000 -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01
# 50%     84692.000000  1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02
# 75%    139320.500000  1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01
# max    172792.000000  2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01
#
#                  V5            V6            V7            V8            V9  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   9.604066e-16  1.487313e-15 -5.556467e-16  1.213481e-16 -2.406331e-15
# ...

# %%
df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
df["Time"].unique()
# Out:
# array([0.00000e+00, 1.00000e+00, 2.00000e+00, ..., 1.72787e+05,
#        1.72788e+05, 1.72792e+05])

# %%
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
x = df.drop(columns="Class",axis=1)
y = df["Class"]

# %%
x
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V20       V21  \
# ...

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 284802    0
# 284803    0
# 284804    0
# 284805    0
# 284806    0
# Name: Class, Length: 284807, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,stratify=y,test_size=0.7,random_state=1)

# %%
x_train
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 169428  119698.0 -0.037200  0.300439 -0.954022  1.393523  2.181413 -1.786380
# 182049  125238.0  2.222321 -0.595123 -1.722452 -1.233165  0.120693 -0.541575
# 125283   77601.0 -1.004271  1.070191  1.232392  0.060345  0.120723 -0.354694
# 87595    61754.0  1.141567 -0.406696  1.247298  0.187551 -1.234753 -0.179288
# 226844  144823.0 -0.321609  1.025110 -0.262052 -0.777570  0.398533 -0.487289
# ...          ...       ...       ...       ...       ...       ...       ...
# 281517  170233.0  1.699834 -1.142560 -0.772505 -0.774131 -0.809416 -0.414268
# 249410  154394.0  1.897380 -0.771054 -0.442537 -0.754800 -0.956791 -0.742104
# 249626  154502.0 -0.312808  1.571520  0.625071  2.851596  1.440896  0.370273
# 188363  127940.0  2.313488 -1.066660 -2.698797 -1.810692  0.181929 -0.825158
# 109955   71615.0 -1.816420  1.479872  0.535462  1.287226 -0.595463  0.024613
#
# ...

# %%
y_train
# Out:
# 169428    0
# 182049    0
# 125283    0
# 87595     0
# 226844    0
#          ..
# 281517    0
# 249410    0
# 249626    0
# 188363    0
# 109955    0
# Name: Class, Length: 85442, dtype: int64

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
p1 = Pipeline([("scaler1",StandardScaler()),("lin_reg",LinearRegression())])
p2 = Pipeline([("rand",RandomForestClassifier())])
p3 = Pipeline([("grad",GradientBoostingClassifier())])
p4 = Pipeline([("decis",DecisionTreeClassifier())])
p5 = Pipeline([("scaler2",StandardScaler()),("log_reg",LogisticRegression())])

# %%
pipelines = [p1,p2,p3,p4,p5]
pipelines
# Out:
# [Pipeline(steps=[('scaler1', StandardScaler()), ('lin_reg', LinearRegression())]),
#  Pipeline(steps=[('rand', RandomForestClassifier())]),
#  Pipeline(steps=[('grad', GradientBoostingClassifier())]),
#  Pipeline(steps=[('decis', DecisionTreeClassifier())]),
#  Pipeline(steps=[('scaler2', StandardScaler()),
#                  ('log_reg', LogisticRegression())])]

# %%
p1.fit(x_train,y_train)
p1.score(x_test,y_test)*100
# Out:
# 54.382997293290835

# %%
p2.fit(x_train,y_train)
p2.score(x_test,y_test)*100
# Out:
# 99.95234870714519

# %%
p3.fit(x_train,y_train)
p3.score(x_test,y_test)*100
# Out:
# 99.91222130263587

# %%
p4.fit(x_train,y_train)
p4.score(x_test,y_test)*100
# Out:
# 99.91874200586864

# %%
p5.fit(x_train,y_train)
p5.score(x_test,y_test)*100
# Out:
# 99.90820856218494

# %%
model = RandomForestClassifier()

# %%
model.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_pred,y_test)
# Out:
# 0.9995335189225791

# %%
input_data = (0,-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62)
input_array = np.asarray(input_data)
input_reshaped_data = input_array.reshape(1,-1)
output = model.predict(input_reshaped_data)

if output==1:
    print("This is a Fraud Transaction")
elif output==0:
    print("This is a Legal Transaction")
# Out:
# This is a Legal Transaction
# C:\Users\tarun\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %%
import pickle

# %%
pickle.dump(model,open("creditcard.pkl","wb"))

# %%
pickled_model=pickle.load(open("creditcard.pkl","rb"))

# %%
input_data = (0,-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62)
input_array = np.asarray(input_data)
input_reshaped_data = input_array.reshape(1,-1)
output = pickled_model.predict(input_reshaped_data)

if output==1:
    print("This is a Fraud Transaction")
elif output==0:
    print("This is a Legal Transaction")
# Out:
# This is a Legal Transaction
# C:\Users\tarun\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(
